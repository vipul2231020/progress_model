# %% [markdown]
# # progress-ml-model
#
# Use the "Run" button to execute the code.

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('data2.csv')

# %%
df
# Out:
#      ProjectID  TaskID  ProjectDuration  TaskDuration  TaskEffort  \
# 0            1     101               60            10          20
# 1            1     102               60            15          30
# 2            1     103               60            30          40
# 3            1     104               60            15          25
# 4            2     201               45             8          18
# ..         ...     ...              ...           ...         ...
# 96          24     346               50            14          22
# 97          25     347               70            14          28
# 98          25     348               70            20          35
# 99          25     349               70            38          50
# 100         25     350               70            16          26
#
#      ResourceAllocation   StartDate     EndDate           Name Domain Assigned
# 0                     3  2023-01-01  2023-02-28  Shaswat Singh          Design
# 1                     2  2023-03-01  2023-04-30   Nidhi Sharma          Design
# 2                     5  2023-05-01  2023-07-01    Arjun Patel              ML
# 3                     4  2023-07-02  2023-08-30    Aarna Singh          Design
# 4                     2  2023-02-01  2023-03-18   Advait Reddy          Mobile
# ..                  ...         ...         ...            ...             ...
# 96                    2  2023-07-16  2023-08-30          Rohit         Backend
# 97                    4  2023-01-10  2023-03-20           Guru          Design
# 98                    3  2023-03-21  2023-05-20       Tanishka        Frontend
# 99                    6  2023-05-21  2023-08-05           Subh         Backend
# 100                   5  2023-08-06  2023-10-15        Devansh              ML
#
# [101 rows x 10 columns]

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error

df['StartDate'] = pd.to_datetime(df['StartDate'])
df['EndDate'] = pd.to_datetime(df['EndDate'])
df['ProjectDuration'] = (df['EndDate'] - df['StartDate']).dt.days
df['TaskStartDate'] = pd.to_datetime(df['StartDate']) + pd.to_timedelta(df['TaskDuration'], unit='D')

# %% [markdown]
# ##  task completion percentage

# %%
df['TaskCompletion'] = (df['TaskDuration'] / df['ProjectDuration']) * 100

# %% [markdown]
# ## Selecting relevant features for training the model

# %%
features = ['ProjectDuration', 'TaskDuration', 'ResourceAllocation']

# %% [markdown]
# ## Applying Linear Regression and splitting training and testing data

# %%
X_train, X_test, y_train, y_test = train_test_split(df[features], df['TaskCompletion'], test_size=0.2, random_state=42)

model = LinearRegression()
model.fit(X_train, y_train)

y_pred = model.predict(X_test)
mae = mean_absolute_error(y_test, y_pred)
print(f'Mean Absolute Error: {mae}')
# Out:
# Mean Absolute Error: 1.6566857477098726

# %% [markdown]
# ## Task Completion prediction

# %%
def evaluate_team_performance(ProjectID=None):
    if ProjectID is not None:
        team_data = df[df['ProjectID'] == ProjectID]

        team_data.loc[:, 'StartDate'] = pd.to_datetime(team_data['StartDate'])
        team_data.loc[:, 'EndDate'] = pd.to_datetime(team_data['EndDate'])
        team_data.loc[:, 'ProjectDuration'] = (team_data['EndDate'] - team_data['StartDate']).dt.days
        team_data.loc[:, 'TaskStartDate'] = team_data['StartDate'] + pd.to_timedelta(team_data['TaskDuration'], unit='D')
        team_data.loc[:, 'TaskCompletion'] = (team_data['TaskDuration'] / team_data['ProjectDuration']) * 100

        team_features = team_data[features]

 
        team_data['PredictedTaskCompletion'] = model.predict(team_features)

        print(f'\nPredicted Task Completion for Project {ProjectID}:')
        print(team_data[['Domain Assigned', 'Name', 'TaskCompletion', 'PredictedTaskCompletion']])
# Out:
# Predicted Task Completion for John Doe:
#          TaskDescription  TaskCompletion  PredictedTaskCompletion
# 0  Requirement Gathering       17.241379                 18.26384
#
# Predicted Task Completion for Jane Smith:
#   TaskDescription  TaskCompletion  PredictedTaskCompletion
# 1          Design            25.0                25.044478
#
# Predicted Task Completion for Bob Johnson:
#   TaskDescription  TaskCompletion  PredictedTaskCompletion
# 2     Development       49.180328                 48.58266
#
# Predicted Task Completion for Alice Williams:
#   TaskDescription  TaskCompletion  PredictedTaskCompletion
# 3         Testing       25.423729                25.780669
#
# Predicted Task Completion for Charlie Brown:
#          TaskDescription  TaskCompletion  PredictedTaskCompletion
# 4  Requirement Gathering       17.777778                21.406887
#
# Predicted Task Completion for Diana Miller:
#   TaskDescription  TaskCompletion  PredictedTaskCompletion
# 5          Design       27.272727                 28.33351
#
# Predicted Task Completion for Edward Davis:
#   TaskDescription  TaskCompletion  PredictedTaskCompletion
# 6     Development       41.666667                41.065831
#
# Predicted Task Completion for Fiona Taylor:
#   TaskDescription  TaskCompletion  PredictedTaskCompletion
# 7         Testing       23.255814                25.550384
#
# Predicted Task Completion for George Robinson:
#          TaskDescription  TaskCompletion  PredictedTaskCompletion
# 8  Requirement Gathering       16.216216                13.639251
#
# Predicted Task Completion for Helen Harris:
#   TaskDescription  TaskCompletion  PredictedTaskCompletion
# 9          Design            30.0                29.899353
#
# Predicted Task Completion for Ivan Martinez:
#    TaskDescription  TaskCompletion  PredictedTaskCompletion
# 10     Development       46.666667                49.679469
#
# Predicted Task Completion for Kate Anderson:
#    TaskDescription  TaskCompletion  PredictedTaskCompletion
# 11         Testing            20.0                18.000278
#
# Predicted Task Completion for Liam Walker:
#            TaskDescription  TaskCompletion  PredictedTaskCompletion
# 12   Requirement Gathering       16.326531                19.552668
# 21                  Design       25.000000                25.044478
# 43                 Testing       25.423729                25.780669
# 55                 Testing       22.222222                24.562689
# 67                 Testing       27.906977                28.706186
# 81                  Design       30.000000                29.778181
# 87                 Testing       27.906977                28.706186
# 101                 Design       30.000000                29.778181
# 106            Development       46.666667                45.799534
# 121                 Design       30.000000                29.778181
# 127                Testing       27.906977                28.706186
# 143                Testing       25.423729                25.780669
# 147                Testing       27.906977                28.706186
# 160  Requirement Gathering       20.689655                21.419642
# 164  Requirement Gathering       22.222222                24.562689
# 167                Testing       27.906977                28.706186
# 181                 Design       30.000000                29.778181
# 187                Testing       27.906977                28.706186
#
# Predicted Task Completion for Mia Turner:
#     TaskDescription  TaskCompletion  PredictedTaskCompletion
# 13           Design       30.612245                30.476803
# 29           Design       30.000000                29.899353
# 51          Testing       20.000000                18.000278
# 69           Design       36.666667                36.210957
# 89           Design       36.666667                36.210957
# 129          Design       36.666667                36.210957
# 149          Design       36.666667                36.210957
# 169          Design       36.666667                36.210957
#
# Predicted Task Completion for Noah Turner:
#            TaskDescription  TaskCompletion  PredictedTaskCompletion
# 14             Development       50.000000                46.004308
# 23                 Testing       25.423729                25.780669
# 63                 Testing       25.423729                25.780669
# 83                 Testing       25.423729                25.780669
# 102            Development       57.377049                56.472165
# 122            Development       57.377049                56.472165
# 140  Requirement Gathering       20.689655                21.419642
# 144  Requirement Gathering       22.222222                24.562689
# 161                 Design       30.000000                29.778181
# 182            Development       57.377049                56.472165
#
# Predicted Task Completion for Olivia Mitchell:
#           TaskDescription  TaskCompletion  PredictedTaskCompletion
# 15                Testing       22.222222                24.562689
# 24  Requirement Gathering       17.777778                21.406887
# 60  Requirement Gathering       20.689655                21.419642
#
# Predicted Task Completion for Peter Ward:
#           TaskDescription  TaskCompletion  PredictedTaskCompletion
# 16  Requirement Gathering       17.391304                16.108489
#
# Predicted Task Completion for Quinn Taylor:
#    TaskDescription  TaskCompletion  PredictedTaskCompletion
# 17          Design            30.0                29.899353
#
# Predicted Task Completion for Ryan Fisher:
#    TaskDescription  TaskCompletion  PredictedTaskCompletion
# 18     Development       46.052632                49.185621
#
# Predicted Task Completion for Sophia Hughes:
#            TaskDescription  TaskCompletion  PredictedTaskCompletion
# 19                 Testing       21.428571                20.469516
# 28   Requirement Gathering       16.216216                13.639251
# 68   Requirement Gathering       20.270270                18.372954
# 88   Requirement Gathering       20.270270                18.372954
# 108  Requirement Gathering       20.270270                18.372954
# 128  Requirement Gathering       20.270270                18.372954
# 148  Requirement Gathering       20.270270                18.372954
# 168  Requirement Gathering       20.270270                18.372954
# 188  Requirement Gathering       20.270270                18.372954
#
# Predicted Task Completion for Emma Davis:
#            TaskDescription  TaskCompletion  PredictedTaskCompletion
# 20   Requirement Gathering       17.241379                18.263840
# 41                  Design       25.000000                25.044478
# 65                  Design       31.818182                31.489312
# 85                  Design       31.818182                31.489312
# 103                Testing       25.423729                25.780669
# 107                Testing       27.906977                28.706186
# 120  Requirement Gathering       20.689655                21.419642
# 125                 Design       31.818182                31.489312
# 142            Development       57.377049                56.472165
# 145                 Design       31.818182                31.489312
# 163                Testing       25.423729                25.780669
# 165                 Design       31.818182                31.489312
# 180  Requirement Gathering       20.689655                21.419642
# 185                 Design       31.818182                31.489312
#
# Predicted Task Completion for Ava Martinez:
#            TaskDescription  TaskCompletion  PredictedTaskCompletion
# 22             Development       49.180328                48.582660
# 62             Development       57.377049                56.472165
# 82             Development       57.377049                56.472165
# 100  Requirement Gathering       20.689655                21.419642
# 123                Testing       25.423729                25.780669
# 141                 Design       30.000000                29.778181
# 162            Development       57.377049                56.472165
# 183                Testing       25.423729                25.780669
#
# Predicted Task Completion for Ethan Harris:
#    TaskDescription  TaskCompletion  PredictedTaskCompletion
# 25          Design       27.272727                28.333510
# 61          Design       30.000000                29.778181
#
# Predicted Task Completion for Isabella Turner:
#            TaskDescription  TaskCompletion  PredictedTaskCompletion
# 26             Development       41.666667                41.065831
# 42             Development       49.180328                48.582660
# 66             Development       46.666667                45.799534
# 80   Requirement Gathering       20.689655                21.419642
# 86             Development       46.666667                45.799534
# 105                 Design       31.818182                31.489312
# 126            Development       46.666667                45.799534
# 146            Development       46.666667                45.799534
# 166            Development       46.666667                45.799534
# 186            Development       46.666667                45.799534
#
# Predicted Task Completion for Aiden Martinez:
#            TaskDescription  TaskCompletion  PredictedTaskCompletion
# 27                 Testing       23.255814                25.550384
# 40   Requirement Gathering       17.241379                18.263840
# 64   Requirement Gathering       22.222222                24.562689
# 84   Requirement Gathering       22.222222                24.562689
# 104  Requirement Gathering       22.222222                24.562689
# 124  Requirement Gathering       22.222222                24.562689
# 184  Requirement Gathering       22.222222                24.562689
#
# Predicted Task Completion for James Taylor:
#     TaskDescription  TaskCompletion  PredictedTaskCompletion
# 30      Development       46.666667                49.679469
# 49           Design       30.000000                29.899353
# 70      Development       53.333333                57.568974
# 90      Development       53.333333                57.568974
# 109          Design       36.666667                36.210957
# 119         Testing       22.857143                22.047417
# 130     Development       53.333333                57.568974
# 150     Development       53.333333                57.568974
# 170     Development       53.333333                57.568974
# 189          Design       36.666667                36.210957
# 199         Testing       22.857143                22.047417
#
# Predicted Task Completion for Grace Walker:
#     TaskDescription  TaskCompletion  PredictedTaskCompletion
# 31          Testing       20.000000                18.000278
# 53           Design       30.612245                30.476803
# 71          Testing       24.000000                22.733981
# 91          Testing       24.000000                22.733981
# 111         Testing       24.000000                22.733981
# 131         Testing       24.000000                22.733981
# 151         Testing       24.000000                22.733981
# 171         Testing       24.000000                22.733981
# 191         Testing       24.000000                22.733981
#
# Predicted Task Completion for Elijah Walker:
#            TaskDescription  TaskCompletion  PredictedTaskCompletion
# 32   Requirement Gathering       17.391304                16.108489
# 50             Development       46.666667                49.679469
# 57                  Design       30.000000                29.899353
# 76   Requirement Gathering       20.289855                19.264291
# 96   Requirement Gathering       20.289855                19.264291
# 110            Development       53.333333                57.568974
# 116  Requirement Gathering       20.289855                19.264291
# 136  Requirement Gathering       20.289855                19.264291
# 156  Requirement Gathering       20.289855                19.264291
# 176  Requirement Gathering       20.289855                19.264291
# 190            Development       53.333333                57.568974
# 196  Requirement Gathering       20.289855                19.264291
#
# Predicted Task Completion for Amelia Turner:
#     TaskDescription  TaskCompletion  PredictedTaskCompletion
# 33           Design       30.000000                29.899353
# 54      Development       50.000000                46.004308
# 77           Design       33.333333                33.055155
# 97           Design       33.333333                33.055155
# 114     Development       60.000000                53.893813
# 137          Design       33.333333                33.055155
# 157          Design       33.333333                33.055155
# 177          Design       33.333333                33.055155
# 194     Development       60.000000                53.893813
#
# Predicted Task Completion for Lucas Fisher:
#     TaskDescription  TaskCompletion  PredictedTaskCompletion
# 34      Development       46.052632                49.185621
# 78      Development       50.000000                53.919324
# 98      Development       50.000000                53.919324
# 118     Development       50.000000                53.919324
# 138     Development       50.000000                53.919324
# 158     Development       50.000000                53.919324
# 178     Development       50.000000                53.919324
# 198     Development       50.000000                53.919324
#
# Predicted Task Completion for Chloe Martinez:
#            TaskDescription  TaskCompletion  PredictedTaskCompletion
# 35                 Testing       21.428571                20.469516
# 44   Requirement Gathering       17.777778                21.406887
# 56   Requirement Gathering       17.391304                16.108489
# 79                 Testing       22.857143                22.047417
# 99                 Testing       22.857143                22.047417
# 117                 Design       33.333333                33.055155
# 139                Testing       22.857143                22.047417
# 159                Testing       22.857143                22.047417
# 179                Testing       22.857143                22.047417
# 197                 Design       33.333333                33.055155
#
# Predicted Task Completion for Logan Fisher:
#            TaskDescription  TaskCompletion  PredictedTaskCompletion
# 36   Requirement Gathering       16.326531                19.552668
# 45                  Design       27.272727                28.333510
# 58             Development       46.052632                49.185621
# 72   Requirement Gathering       20.408163                22.708470
# 92   Requirement Gathering       20.408163                22.708470
# 112  Requirement Gathering       20.408163                22.708470
# 132  Requirement Gathering       20.408163                22.708470
# 152  Requirement Gathering       20.408163                22.708470
# 172  Requirement Gathering       20.408163                22.708470
# 192  Requirement Gathering       20.408163                22.708470
#
# Predicted Task Completion for Aria Martinez:
#     TaskDescription  TaskCompletion  PredictedTaskCompletion
# 37           Design       30.612245                30.476803
# 47          Testing       23.255814                25.550384
# 59          Testing       21.428571                20.469516
# 73           Design       32.653061                32.054704
# 93           Design       32.653061                32.054704
# 133          Design       32.653061                32.054704
# 153          Design       32.653061                32.054704
# 173          Design       32.653061                32.054704
#
# Predicted Task Completion for Henry Turner:
#            TaskDescription  TaskCompletion  PredictedTaskCompletion
# 38             Development       50.000000                46.004308
# 46             Development       41.666667                41.065831
# 52   Requirement Gathering       16.326531                19.552668
# 74             Development       60.000000                53.893813
# 94             Development       60.000000                53.893813
# 115                Testing       31.111111                30.874293
# 134            Development       60.000000                53.893813
# 154            Development       60.000000                53.893813
# 174            Development       60.000000                53.893813
# 195                Testing       31.111111                30.874293
#
# Predicted Task Completion for Scarlett Hughes:
#            TaskDescription  TaskCompletion  PredictedTaskCompletion
# 39                 Testing       22.222222                24.562689
# 48   Requirement Gathering       16.216216                13.639251
# 75                 Testing       31.111111                30.874293
# 95                 Testing       31.111111                30.874293
# 113                 Design       32.653061                32.054704
# 135                Testing       31.111111                30.874293
# 155                Testing       31.111111                30.874293
# 175                Testing       31.111111                30.874293
# 193                 Design       32.653061                32.054704
# /tmp/ipykernel_45/766727676.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   member_data['PredictedTaskCompletion'] = model.predict(member_features)
# /tmp/ipykernel_45/766727676.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   member_data['PredictedTaskCompletion'] = model.predict(member_features)
# /tmp/ipykernel_45/766727676.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   member_data['PredictedTaskCompletion'] = model.predict(member_features)
# /tmp/ipykernel_45/766727676.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   member_data['PredictedTaskCompletion'] = model.predict(member_features)
# /tmp/ipykernel_45/766727676.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   member_data['PredictedTaskCompletion'] = model.predict(member_features)
# /tmp/ipykernel_45/766727676.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   member_data['PredictedTaskCompletion'] = model.predict(member_features)
# /tmp/ipykernel_45/766727676.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   member_data['PredictedTaskCompletion'] = model.predict(member_features)
# /tmp/ipykernel_45/766727676.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   member_data['PredictedTaskCompletion'] = model.predict(member_features)
# /tmp/ipykernel_45/766727676.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   member_data['PredictedTaskCompletion'] = model.predict(member_features)
# /tmp/ipykernel_45/766727676.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   member_data['PredictedTaskCompletion'] = model.predict(member_features)
# /tmp/ipykernel_45/766727676.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   member_data['PredictedTaskCompletion'] = model.predict(member_features)
# /tmp/ipykernel_45/766727676.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   member_data['PredictedTaskCompletion'] = model.predict(member_features)
# /tmp/ipykernel_45/766727676.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   member_data['PredictedTaskCompletion'] = model.predict(member_features)
# /tmp/ipykernel_45/766727676.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   member_data['PredictedTaskCompletion'] = model.predict(member_features)
# /tmp/ipykernel_45/766727676.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   member_data['PredictedTaskCompletion'] = model.predict(member_features)
# /tmp/ipykernel_45/766727676.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   member_data['PredictedTaskCompletion'] = model.predict(member_features)
# /tmp/ipykernel_45/766727676.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   member_data['PredictedTaskCompletion'] = model.predict(member_features)
# /tmp/ipykernel_45/766727676.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   member_data['PredictedTaskCompletion'] = model.predict(member_features)
# /tmp/ipykernel_45/766727676.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   member_data['PredictedTaskCompletion'] = model.predict(member_features)
# /tmp/ipykernel_45/766727676.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   member_data['PredictedTaskCompletion'] = model.predict(member_features)
# /tmp/ipykernel_45/766727676.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   member_data['PredictedTaskCompletion'] = model.predict(member_features)
# /tmp/ipykernel_45/766727676.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   member_data['PredictedTaskCompletion'] = model.predict(member_features)
# /tmp/ipykernel_45/766727676.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   member_data['PredictedTaskCompletion'] = model.predict(member_features)
# /tmp/ipykernel_45/766727676.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   member_data['PredictedTaskCompletion'] = model.predict(member_features)
# /tmp/ipykernel_45/766727676.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   member_data['PredictedTaskCompletion'] = model.predict(member_features)
# /tmp/ipykernel_45/766727676.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   member_data['PredictedTaskCompletion'] = model.predict(member_features)
# /tmp/ipykernel_45/766727676.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   member_data['PredictedTaskCompletion'] = model.predict(member_features)
# /tmp/ipykernel_45/766727676.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   member_data['PredictedTaskCompletion'] = model.predict(member_features)
# /tmp/ipykernel_45/766727676.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   member_data['PredictedTaskCompletion'] = model.predict(member_features)
# /tmp/ipykernel_45/766727676.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   member_data['PredictedTaskCompletion'] = model.predict(member_features)
# /tmp/ipykernel_45/766727676.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   member_data['PredictedTaskCompletion'] = model.predict(member_features)
# /tmp/ipykernel_45/766727676.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   member_data['PredictedTaskCompletion'] = model.predict(member_features)
# /tmp/ipykernel_45/766727676.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   member_data['PredictedTaskCompletion'] = model.predict(member_features)
# /tmp/ipykernel_45/766727676.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   member_data['PredictedTaskCompletion'] = model.predict(member_features)
# /tmp/ipykernel_45/766727676.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   member_data['PredictedTaskCompletion'] = model.predict(member_features)
